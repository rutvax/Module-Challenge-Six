# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 605

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
# Define an empty list to fetch the weather data for each city
city_data = []

# %%
# Print to logger
print("Beginning Data Retrieval")
print("-----------------------------")


# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data list
        city_data.append({
            "City" :city,
            "Lat" :city_lat,
            "Lng" :city_lng,
            "Max Temp" :city_max_temp,
            "Humidity" :city_humidity,
            "Cloudiness" :city_clouds,
            "Windspeed" :city_wind,
            "Country" :city_country,
            "Date" :city_date  
        })

     # If an error is experienced, skip the city
    except:
        print("City not found. Skipping ...")
        pass
# Indicate that data loading is complete
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | mirnyy
# Processing Record 4 of Set 1 | extrema
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | callao
# Processing Record 8 of Set 1 | college
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | puerto natales
# Processing Record 11 of Set 1 | port douglas
# Processing Record 12 of Set 1 | talnakh
# Processing Record 13 of Set 1 | bafq
# Processing Record 14 of Set 1 | ust-nera
# Processing Record 15 of Set 1 | haiku-pauwela
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | vingt cinq
# City not found. Skipping ...
# Processing Record 18 of Set 1 | nar'yan-mar
# Processing Record 19 of Set 1 | 'ohonua
# City not found. Skipping ...
# Processing Record 20 of Set 1 | pionerskiy
# Processing Record 21 of Set 1 | alcains
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | usogorsk
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | andalgala
# Processing Record 27 of Set 1 | blackmans bay
# Processing Record 28 of Set 1 | jayapura
# Processing Record 29 of Set 1 | seaside
# Processing Record 30 of Set 1 | funtua
# Processing Record 31 of Set 1 | tsiombe
# Processing Record 32 of Set 1 | san ignacio de velasco
# Processing Record 33 of Set 1 | bilibino
# Processing Record 34 of Set 1 | afaahiti
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | west island
# Processing Record 37 of Set 1 | vadso
# Processing Record 38 of Set 1 | zeya
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | grytviken
# Processing Record 41 of Set 1 | tura
# Processing Record 42 of Set 1 | walvis bay
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | olonkinbyen
# Processing Record 45 of Set 1 | kotlas
# Processing Record 46 of Set 1 | wynyard
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | labuan
# Processing Record 49 of Set 1 | qaqortoq
# Processing Record 50 of Set 1 | kimbe
# Processing Record 0 of Set 2 | papatowai
# Processing Record 1 of Set 2 | taiohae
# City not found. Skipping ...
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | kulia village
# City not found. Skipping ...
# Processing Record 4 of Set 2 | flin flon
# Processing Record 5 of Set 2 | fortaleza
# Processing Record 6 of Set 2 | ortaca
# Processing Record 7 of Set 2 | nagqu
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | hayma'
# City not found. Skipping ...
# Processing Record 10 of Set 2 | homer
# Processing Record 11 of Set 2 | mejit
# Processing Record 12 of Set 2 | vilyuchinsk
# Processing Record 13 of Set 2 | kapuskasing
# Processing Record 14 of Set 2 | badger
# Processing Record 15 of Set 2 | edinburgh of the seven seas
# Processing Record 16 of Set 2 | rongelap
# Processing Record 17 of Set 2 | enewetak
# Processing Record 18 of Set 2 | conakry
# Processing Record 19 of Set 2 | ancud
# Processing Record 20 of Set 2 | kavaratti
# Processing Record 21 of Set 2 | nicoya
# Processing Record 22 of Set 2 | hadibu
# Processing Record 23 of Set 2 | gebeit
# Processing Record 24 of Set 2 | ust-tsilma
# Processing Record 25 of Set 2 | novomikhaylovskiy
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | hasaki
# Processing Record 28 of Set 2 | mateur
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | tobi village
# City not found. Skipping ...
# Processing Record 31 of Set 2 | katsuura
# Processing Record 32 of Set 2 | constantia
# Processing Record 33 of Set 2 | sodra sandby
# Processing Record 34 of Set 2 | puerto san carlos
# City not found. Skipping ...
# Processing Record 35 of Set 2 | invercargill
# Processing Record 36 of Set 2 | al 'alamayn
# City not found. Skipping ...
# Processing Record 37 of Set 2 | barra do garcas
# Processing Record 38 of Set 2 | chibougamau
# Processing Record 39 of Set 2 | deqen
# Processing Record 40 of Set 2 | hawaiian paradise park
# Processing Record 41 of Set 2 | chonchi
# Processing Record 42 of Set 2 | khowy
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | esikhaleni
# Processing Record 45 of Set 2 | cuamba
# Processing Record 46 of Set 2 | tazacorte
# Processing Record 47 of Set 2 | ayr
# Processing Record 48 of Set 2 | oriximina
# Processing Record 49 of Set 2 | konarka
# Processing Record 0 of Set 3 | whitehorse
# Processing Record 1 of Set 3 | klyuchi
# Processing Record 2 of Set 3 | vernon
# Processing Record 3 of Set 3 | taltal
# Processing Record 4 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 3 | palikir - national government center
# Processing Record 6 of Set 3 | aasiaat
# Processing Record 7 of Set 3 | salym
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | guerrero negro
# Processing Record 10 of Set 3 | lazaro cardenas
# Processing Record 11 of Set 3 | stanley
# Processing Record 12 of Set 3 | howard springs
# Processing Record 13 of Set 3 | pasuquin
# Processing Record 14 of Set 3 | tromso
# Processing Record 15 of Set 3 | qui nhon
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | nemuro
# Processing Record 18 of Set 3 | grajau
# Processing Record 19 of Set 3 | muzayri'
# City not found. Skipping ...
# Processing Record 20 of Set 3 | sao tome
# Processing Record 21 of Set 3 | barcelos
# Processing Record 22 of Set 3 | cabedelo
# Processing Record 23 of Set 3 | san juan bautista
# Processing Record 24 of Set 3 | simsbury center
# Processing Record 25 of Set 3 | udachny
# Processing Record 26 of Set 3 | kenai
# Processing Record 27 of Set 3 | yellowknife
# Processing Record 28 of Set 3 | labytnangi
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | bandar lampung
# Processing Record 31 of Set 3 | tabou
# Processing Record 32 of Set 3 | essaouira
# Processing Record 33 of Set 3 | puerto ayora
# Processing Record 34 of Set 3 | aripuana
# Processing Record 35 of Set 3 | gizo
# Processing Record 36 of Set 3 | pontes e lacerda
# Processing Record 37 of Set 3 | mount isa
# Processing Record 38 of Set 3 | baissa
# Processing Record 39 of Set 3 | trairi
# Processing Record 40 of Set 3 | crane
# Processing Record 41 of Set 3 | sur
# Processing Record 42 of Set 3 | qamdo
# Processing Record 43 of Set 3 | hastings
# Processing Record 44 of Set 3 | isafjordur
# Processing Record 45 of Set 3 | acapulco de juarez
# Processing Record 46 of Set 3 | weiser
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | suva
# Processing Record 49 of Set 3 | margaret river
# Processing Record 0 of Set 4 | zaqatala
# Processing Record 1 of Set 4 | vorgashor
# Processing Record 2 of Set 4 | laayoune plage
# City not found. Skipping ...
# Processing Record 3 of Set 4 | livingston
# Processing Record 4 of Set 4 | rio grande
# Processing Record 5 of Set 4 | homestead meadows south
# Processing Record 6 of Set 4 | la paz
# Processing Record 7 of Set 4 | bel ombre
# Processing Record 8 of Set 4 | cestos city
# Processing Record 9 of Set 4 | falam
# Processing Record 10 of Set 4 | cidreira
# Processing Record 11 of Set 4 | paciran
# Processing Record 12 of Set 4 | buzdyak
# Processing Record 13 of Set 4 | puerto santa
# Processing Record 14 of Set 4 | puerto armuelles
# Processing Record 15 of Set 4 | chaman
# Processing Record 16 of Set 4 | gamba
# Processing Record 17 of Set 4 | avarua
# Processing Record 18 of Set 4 | kapa'a
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | miandrivazo
# Processing Record 21 of Set 4 | sechura
# Processing Record 22 of Set 4 | weno
# Processing Record 23 of Set 4 | mana
# Processing Record 24 of Set 4 | puerto aysen
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | kununurra
# Processing Record 27 of Set 4 | heihe
# Processing Record 28 of Set 4 | selfoss
# Processing Record 29 of Set 4 | sola
# Processing Record 30 of Set 4 | nova sintra
# Processing Record 31 of Set 4 | kingston
# Processing Record 32 of Set 4 | plastun
# Processing Record 33 of Set 4 | saldanha
# Processing Record 34 of Set 4 | sassandra
# Processing Record 35 of Set 4 | nurota
# Processing Record 36 of Set 4 | morondava
# Processing Record 37 of Set 4 | ulanhot
# Processing Record 38 of Set 4 | makamba
# Processing Record 39 of Set 4 | howrah
# Processing Record 40 of Set 4 | castillos
# Processing Record 41 of Set 4 | iskateley
# Processing Record 42 of Set 4 | lihue
# Processing Record 43 of Set 4 | taroa
# Processing Record 44 of Set 4 | la passe
# Processing Record 45 of Set 4 | fale old settlement
# Processing Record 46 of Set 4 | saacow
# Processing Record 47 of Set 4 | kone
# Processing Record 48 of Set 4 | kasempa
# Processing Record 49 of Set 4 | utrik
# Processing Record 0 of Set 5 | igarka
# Processing Record 1 of Set 5 | guano
# Processing Record 2 of Set 5 | hammerfest
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | nuuk
# Processing Record 5 of Set 5 | pimentel
# Processing Record 6 of Set 5 | balabac
# Processing Record 7 of Set 5 | carbonear
# Processing Record 8 of Set 5 | berdigestyakh
# Processing Record 9 of Set 5 | balikpapan
# Processing Record 10 of Set 5 | sinsang-ni
# Processing Record 11 of Set 5 | jianshui
# Processing Record 12 of Set 5 | emmett
# Processing Record 13 of Set 5 | pervomayskoye
# Processing Record 14 of Set 5 | mahalapye
# Processing Record 15 of Set 5 | kerrville
# Processing Record 16 of Set 5 | kargasok
# Processing Record 17 of Set 5 | quellon
# Processing Record 18 of Set 5 | badr hunayn
# Processing Record 19 of Set 5 | punta arenas
# Processing Record 20 of Set 5 | lorengau
# Processing Record 21 of Set 5 | pangoa
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | morant bay
# Processing Record 24 of Set 5 | sitka
# Processing Record 25 of Set 5 | atafu village
# Processing Record 26 of Set 5 | maile
# Processing Record 27 of Set 5 | port saint john's
# Processing Record 28 of Set 5 | ciudad bolivar
# Processing Record 29 of Set 5 | bengkulu
# Processing Record 30 of Set 5 | kingscliff
# Processing Record 31 of Set 5 | abalak
# Processing Record 32 of Set 5 | sao raimundo nonato
# Processing Record 33 of Set 5 | lautoka
# Processing Record 34 of Set 5 | curuca
# Processing Record 35 of Set 5 | amga
# Processing Record 36 of Set 5 | northam
# Processing Record 37 of Set 5 | vakarai
# Processing Record 38 of Set 5 | gokarna
# Processing Record 39 of Set 5 | arkhangel'sk
# Processing Record 40 of Set 5 | yenotayevka
# Processing Record 41 of Set 5 | tiksi
# Processing Record 42 of Set 5 | uturoa
# Processing Record 43 of Set 5 | devinuwara
# City not found. Skipping ...
# Processing Record 44 of Set 5 | wailua homesteads
# Processing Record 45 of Set 5 | caconda
# Processing Record 46 of Set 5 | alotau
# City not found. Skipping ...
# Processing Record 47 of Set 5 | pak phanang
# Processing Record 48 of Set 5 | okha
# Processing Record 49 of Set 5 | dwarka
# Processing Record 0 of Set 6 | ambodifotatra
# Processing Record 1 of Set 6 | fort bragg
# Processing Record 2 of Set 6 | cockburn town
# Processing Record 3 of Set 6 | camabatela
# Processing Record 4 of Set 6 | recco
# Processing Record 5 of Set 6 | waingapu
# Processing Record 6 of Set 6 | san jose
# Processing Record 7 of Set 6 | kailua-kona
# Processing Record 8 of Set 6 | kayangel
# Processing Record 9 of Set 6 | tselina
# Processing Record 10 of Set 6 | vorkuta
# Processing Record 11 of Set 6 | minas de marcona
# Processing Record 12 of Set 6 | bentiu
# Processing Record 13 of Set 6 | ermelo
# Processing Record 14 of Set 6 | port glaud
# City not found. Skipping ...
# Processing Record 15 of Set 6 | arkalyk
# Processing Record 16 of Set 6 | stolac
# Processing Record 17 of Set 6 | kuytun
# Processing Record 18 of Set 6 | luderitz
# Processing Record 19 of Set 6 | nova vicosa
# Processing Record 20 of Set 6 | santa ines
# Processing Record 21 of Set 6 | tazovsky
# Processing Record 22 of Set 6 | chinde
# Processing Record 23 of Set 6 | tadine
# Processing Record 24 of Set 6 | tolanaro
# Processing Record 25 of Set 6 | lijiang
# Processing Record 26 of Set 6 | tarawa
# Processing Record 27 of Set 6 | maintirano
# Processing Record 28 of Set 6 | north platte
# Processing Record 29 of Set 6 | alaghsas
# Processing Record 30 of Set 6 | kruisfontein
# Processing Record 31 of Set 6 | rio gallegos
# Processing Record 32 of Set 6 | governor's harbour
# City not found. Skipping ...
# Processing Record 33 of Set 6 | port mathurin
# Processing Record 34 of Set 6 | conception bay south
# Processing Record 35 of Set 6 | kosh-agach
# Processing Record 36 of Set 6 | sarmiento
# Processing Record 37 of Set 6 | jiazi
# Processing Record 38 of Set 6 | linhares
# Processing Record 39 of Set 6 | mount gambier
# Processing Record 40 of Set 6 | kristiansund
# Processing Record 41 of Set 6 | hamilton
# Processing Record 42 of Set 6 | edson
# Processing Record 43 of Set 6 | al qusiyah
# Processing Record 44 of Set 6 | itaituba
# Processing Record 45 of Set 6 | zahedan
# Processing Record 46 of Set 6 | milton
# Processing Record 47 of Set 6 | ksar chellala
# Processing Record 48 of Set 6 | keflavik
# Processing Record 49 of Set 6 | cargados carajos
# City not found. Skipping ...
# Processing Record 0 of Set 7 | gurupi
# Processing Record 1 of Set 7 | shalqar
# Processing Record 2 of Set 7 | coahuayana de hidalgo
# Processing Record 3 of Set 7 | gadzhiyevo
# Processing Record 4 of Set 7 | asadabad
# Processing Record 5 of Set 7 | akdepe
# Processing Record 6 of Set 7 | ranohira
# City not found. Skipping ...
# Processing Record 7 of Set 7 | yima
# Processing Record 8 of Set 7 | malpe
# Processing Record 9 of Set 7 | bayganin
# Processing Record 10 of Set 7 | praia da vitoria
# Processing Record 11 of Set 7 | tanjung selor
# City not found. Skipping ...
# Processing Record 12 of Set 7 | susuman
# Processing Record 13 of Set 7 | palu
# Processing Record 14 of Set 7 | emerald
# Processing Record 15 of Set 7 | yamada
# Processing Record 16 of Set 7 | kelibia
# Processing Record 17 of Set 7 | kalmunai
# Processing Record 18 of Set 7 | saint-pierre
# Processing Record 19 of Set 7 | cascais
# Processing Record 20 of Set 7 | chiang mai
# Processing Record 21 of Set 7 | naracoorte
# Processing Record 22 of Set 7 | rockford
# Processing Record 23 of Set 7 | charikar
# Processing Record 24 of Set 7 | benguela
# Processing Record 25 of Set 7 | inirida
# Processing Record 26 of Set 7 | westport
# Processing Record 27 of Set 7 | laikit, laikit ii (dimembe)
# Processing Record 28 of Set 7 | bamboo flat
# Processing Record 29 of Set 7 | graham
# Processing Record 30 of Set 7 | north bend
# Processing Record 31 of Set 7 | saint-francois
# Processing Record 32 of Set 7 | dudinka
# Processing Record 33 of Set 7 | filakovo
# Processing Record 34 of Set 7 | ratlam
# Processing Record 35 of Set 7 | diebougou
# Processing Record 36 of Set 7 | villeneuve-sur-yonne
# Processing Record 37 of Set 7 | miracema do tocantins
# Processing Record 38 of Set 7 | shanga
# Processing Record 39 of Set 7 | hami
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | kencong
# Processing Record 42 of Set 7 | devon
# Processing Record 43 of Set 7 | fort-shevchenko
# Processing Record 44 of Set 7 | veinticinco de mayo
# Processing Record 45 of Set 7 | st. john's
# Processing Record 46 of Set 7 | grand-lahou
# Processing Record 47 of Set 7 | papao
# Processing Record 48 of Set 7 | marsh harbour
# Processing Record 49 of Set 7 | yuzhno-kurilsk
# Processing Record 0 of Set 8 | collie
# Processing Record 1 of Set 8 | hihifo
# City not found. Skipping ...
# Processing Record 2 of Set 8 | holualoa
# Processing Record 3 of Set 8 | port alfred
# Processing Record 4 of Set 8 | inyonga
# Processing Record 5 of Set 8 | gelendost
# Processing Record 6 of Set 8 | junction city
# Processing Record 7 of Set 8 | betare oya
# Processing Record 8 of Set 8 | kudymkar
# Processing Record 9 of Set 8 | coquimbo
# Processing Record 10 of Set 8 | kolonia
# Processing Record 11 of Set 8 | chengzhong
# Processing Record 12 of Set 8 | iskushuban
# Processing Record 13 of Set 8 | luang namtha
# Processing Record 14 of Set 8 | caleta de carquin
# Processing Record 15 of Set 8 | remire-montjoly
# Processing Record 16 of Set 8 | guinticgan
# Processing Record 17 of Set 8 | mawu
# Processing Record 18 of Set 8 | wad az zaki
# Processing Record 19 of Set 8 | pisco
# Processing Record 20 of Set 8 | taungoo
# Processing Record 21 of Set 8 | energetik
# Processing Record 22 of Set 8 | ust'-charyshskaya pristan'
# Processing Record 23 of Set 8 | soe
# Processing Record 24 of Set 8 | stanisic
# Processing Record 25 of Set 8 | palmas
# Processing Record 26 of Set 8 | mogocha
# Processing Record 27 of Set 8 | mugia
# Processing Record 28 of Set 8 | san andres
# Processing Record 29 of Set 8 | tambura
# Processing Record 30 of Set 8 | pico truncado
# Processing Record 31 of Set 8 | colonia
# Processing Record 32 of Set 8 | fukuecho
# Processing Record 33 of Set 8 | san patricio
# Processing Record 34 of Set 8 | sopron
# Processing Record 35 of Set 8 | oranjemund
# Processing Record 36 of Set 8 | mitsamiouli
# Processing Record 37 of Set 8 | la'ie
# Processing Record 38 of Set 8 | antigo
# Processing Record 39 of Set 8 | omutinskiy
# Processing Record 40 of Set 8 | angaur state
# Processing Record 41 of Set 8 | san fernando del valle de catamarca
# Processing Record 42 of Set 8 | wichian buri
# Processing Record 43 of Set 8 | miles city
# Processing Record 44 of Set 8 | fisterra
# Processing Record 45 of Set 8 | cuyo
# Processing Record 46 of Set 8 | ghat
# Processing Record 47 of Set 8 | novaya igirma
# Processing Record 48 of Set 8 | dakhla
# Processing Record 49 of Set 8 | ornskoldsvik
# Processing Record 0 of Set 9 | taco pozo
# Processing Record 1 of Set 9 | rosalie
# Processing Record 2 of Set 9 | kiunga
# Processing Record 3 of Set 9 | san antonio de pale
# Processing Record 4 of Set 9 | beroroha
# Processing Record 5 of Set 9 | cukai
# Processing Record 6 of Set 9 | alvaraes
# Processing Record 7 of Set 9 | ineu
# Processing Record 8 of Set 9 | khandyga
# Processing Record 9 of Set 9 | flying fish cove
# Processing Record 10 of Set 9 | kupang
# Processing Record 11 of Set 9 | timbuktu
# Processing Record 12 of Set 9 | ola
# Processing Record 13 of Set 9 | brak
# Processing Record 14 of Set 9 | coruripe
# Processing Record 15 of Set 9 | burela de cabo
# Processing Record 16 of Set 9 | lucapa
# Processing Record 17 of Set 9 | ibiza
# Processing Record 18 of Set 9 | bhuban
# Processing Record 19 of Set 9 | happy valley-goose bay
# Processing Record 20 of Set 9 | nogliki
# Processing Record 21 of Set 9 | rumonge
# Processing Record 22 of Set 9 | saipan
# Processing Record 23 of Set 9 | nevada
# Processing Record 24 of Set 9 | antsiranana
# Processing Record 25 of Set 9 | al jawf
# Processing Record 26 of Set 9 | sona
# Processing Record 27 of Set 9 | ulladulla
# Processing Record 28 of Set 9 | alta gracia
# Processing Record 29 of Set 9 | el calafate
# Processing Record 30 of Set 9 | ta`u
# Processing Record 31 of Set 9 | nokia
# Processing Record 32 of Set 9 | baiao
# Processing Record 33 of Set 9 | nejo
# Processing Record 34 of Set 9 | farafangana
# Processing Record 35 of Set 9 | berezovyy
# Processing Record 36 of Set 9 | egilsstadir
# Processing Record 37 of Set 9 | nouadhibou
# Processing Record 38 of Set 9 | tuy hoa
# Processing Record 39 of Set 9 | rikaze
# Processing Record 40 of Set 9 | conceicao do araguaia
# Processing Record 41 of Set 9 | nyurba
# Processing Record 42 of Set 9 | manga
# Processing Record 43 of Set 9 | cidade velha
# Processing Record 44 of Set 9 | mount pleasant
# Processing Record 45 of Set 9 | las tablas
# Processing Record 46 of Set 9 | port augusta
# Processing Record 47 of Set 9 | katsuren-haebaru
# Processing Record 48 of Set 9 | yagry
# City not found. Skipping ...
# Processing Record 49 of Set 9 | kittila
# Processing Record 0 of Set 10 | okhotsk
# Processing Record 1 of Set 10 | champerico
# Processing Record 2 of Set 10 | guanare
# Processing Record 3 of Set 10 | itatiba
# Processing Record 4 of Set 10 | sunland park
# Processing Record 5 of Set 10 | monte alegre
# Processing Record 6 of Set 10 | olinda
# Processing Record 7 of Set 10 | zinjibar
# Processing Record 8 of Set 10 | akureyri
# Processing Record 9 of Set 10 | cannonvale
# Processing Record 10 of Set 10 | weiz
# Processing Record 11 of Set 10 | sao vicente
# Processing Record 12 of Set 10 | sorong
# Processing Record 13 of Set 10 | gates-north gates
# City not found. Skipping ...
# Processing Record 14 of Set 10 | gornopravdinsk
# Processing Record 15 of Set 10 | kretinga
# Processing Record 16 of Set 10 | aswan
# Processing Record 17 of Set 10 | bestobe
# Processing Record 18 of Set 10 | tranovaho
# City not found. Skipping ...
# Processing Record 19 of Set 10 | santa rosa del sur
# Processing Record 20 of Set 10 | asau
# Processing Record 21 of Set 10 | dazhou
# Processing Record 22 of Set 10 | conceicao da barra
# Processing Record 23 of Set 10 | sabang
# Processing Record 24 of Set 10 | tinajo
# Processing Record 25 of Set 10 | new norfolk
# Processing Record 26 of Set 10 | kavarna
# Processing Record 27 of Set 10 | tralee
# Processing Record 28 of Set 10 | cabo san lucas
# Processing Record 29 of Set 10 | harnosand
# Processing Record 30 of Set 10 | puerto baquerizo moreno
# Processing Record 31 of Set 10 | villa gesell
# Processing Record 32 of Set 10 | bereznik
# Processing Record 33 of Set 10 | tres arroyos
# Processing Record 34 of Set 10 | abuyog
# Processing Record 35 of Set 10 | tindouf
# Processing Record 36 of Set 10 | semirom
# Processing Record 37 of Set 10 | usinsk
# Processing Record 38 of Set 10 | xinzhi
# Processing Record 39 of Set 10 | midvagur
# Processing Record 40 of Set 10 | alice springs
# Processing Record 41 of Set 10 | quintanar de la orden
# Processing Record 42 of Set 10 | zouerate
# Processing Record 43 of Set 10 | kizel
# Processing Record 44 of Set 10 | krasnokamensk
# Processing Record 45 of Set 10 | ulsteinvik
# Processing Record 46 of Set 10 | inebolu
# Processing Record 47 of Set 10 | east ballina
# Processing Record 48 of Set 10 | amursk
# Processing Record 49 of Set 10 | port hueneme
# Processing Record 0 of Set 11 | ataq
# Processing Record 1 of Set 11 | ixtapa
# Processing Record 2 of Set 11 | bubaque
# Processing Record 3 of Set 11 | polyarnyy
# Processing Record 4 of Set 11 | preobrazheniye
# Processing Record 5 of Set 11 | jackson
# Processing Record 6 of Set 11 | akrehamn
# Processing Record 7 of Set 11 | touros
# Processing Record 8 of Set 11 | beau vallon
# Processing Record 9 of Set 11 | inekar
# City not found. Skipping ...
# Processing Record 10 of Set 11 | coronel dorrego
# Processing Record 11 of Set 11 | ak-suu
# Processing Record 12 of Set 11 | singaparna
# Processing Record 13 of Set 11 | taoyuan city
# Processing Record 14 of Set 11 | severo-yeniseyskiy
# Processing Record 15 of Set 11 | serhiyivka
# Processing Record 16 of Set 11 | mount pearl
# Processing Record 17 of Set 11 | kashary
# Processing Record 18 of Set 11 | naze
# Processing Record 19 of Set 11 | fort st. john
# Processing Record 20 of Set 11 | oncativo
# Processing Record 21 of Set 11 | samarra'
# City not found. Skipping ...
# Processing Record 22 of Set 11 | vila franca do campo
# Processing Record 23 of Set 11 | hafar al-batin
# Processing Record 24 of Set 11 | jalalpur pirwala
# Processing Record 25 of Set 11 | laela
# Processing Record 26 of Set 11 | novodvinsk
# Processing Record 27 of Set 11 | kuanda
# Processing Record 28 of Set 11 | jose mariano jimenez
# City not found. Skipping ...
# Processing Record 29 of Set 11 | wanning
# Processing Record 30 of Set 11 | mandalgovi
# Processing Record 31 of Set 11 | medicine hat
# Processing Record 32 of Set 11 | olyokminsk
# Processing Record 33 of Set 11 | grand falls-windsor
# Processing Record 34 of Set 11 | la chorrera
# Processing Record 35 of Set 11 | terenos
# Processing Record 36 of Set 11 | abbeville
# Processing Record 37 of Set 11 | fuvahmulah
# City not found. Skipping ...
# Processing Record 38 of Set 11 | beypazari
# Processing Record 39 of Set 11 | tahoua
# Processing Record 40 of Set 11 | grand baie
# Processing Record 41 of Set 11 | kasongo-lunda
# Processing Record 42 of Set 11 | san luis de la loma
# Processing Record 43 of Set 11 | xicotencatl
# Processing Record 44 of Set 11 | koh kong
# Processing Record 45 of Set 11 | whakatane
# Processing Record 46 of Set 11 | kiyawa
# City not found. Skipping ...
# Processing Record 47 of Set 11 | toga village
# City not found. Skipping ...
# Processing Record 48 of Set 11 | clawson
# Processing Record 49 of Set 11 | piney green
# Processing Record 0 of Set 12 | maua
# Processing Record 1 of Set 12 | carolina
# Processing Record 2 of Set 12 | auxonne
# Processing Record 3 of Set 12 | kamogawa
# Processing Record 4 of Set 12 | ak'ordat
# Processing Record 5 of Set 12 | murwara
# Processing Record 6 of Set 12 | stepnogorsk
# Processing Record 7 of Set 12 | north branch
# Processing Record 8 of Set 12 | mont-laurier
# Processing Record 9 of Set 12 | toulepleu guere
# Processing Record 10 of Set 12 | starkville
# Processing Record 11 of Set 12 | calabugao
# Processing Record 12 of Set 12 | vilyuysk
# Processing Record 13 of Set 12 | kourou
# Processing Record 14 of Set 12 | merrill
# Processing Record 15 of Set 12 | nantucket
# Processing Record 16 of Set 12 | del rio
# Processing Record 17 of Set 12 | armacao de buzios
# Processing Record 18 of Set 12 | wenchang
# Processing Record 19 of Set 12 | frontera
# Processing Record 20 of Set 12 | monze
# Processing Record 21 of Set 12 | tangalle
# Processing Record 22 of Set 12 | belyy yar
# Processing Record 23 of Set 12 | camana
# Processing Record 24 of Set 12 | antalaha
# Processing Record 25 of Set 12 | les cayes
# Processing Record 26 of Set 12 | totskoye
# Processing Record 27 of Set 12 | el nido
# Processing Record 28 of Set 12 | ujae
# Processing Record 29 of Set 12 | kirensk
# Processing Record 30 of Set 12 | yemetsk
# Processing Record 31 of Set 12 | tsiroanomandidy
# Processing Record 32 of Set 12 | terenozek
# Processing Record 33 of Set 12 | sherman
# Processing Record 34 of Set 12 | murzuq
# Processing Record 35 of Set 12 | la ronge
# Processing Record 36 of Set 12 | evanston
# Processing Record 37 of Set 12 | harstad
# Processing Record 38 of Set 12 | jabor
# Processing Record 39 of Set 12 | magadan
# Processing Record 40 of Set 12 | gaspe
# Processing Record 41 of Set 12 | moyale
# Processing Record 42 of Set 12 | pimenta bueno
# Processing Record 43 of Set 12 | tete
# Processing Record 44 of Set 12 | kishtwar
# Processing Record 45 of Set 12 | malvan
# Processing Record 46 of Set 12 | saynshand
# Processing Record 47 of Set 12 | dunedin
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Windspeed     571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             kodiak  57.7900 -152.4072     42.31        81         100
# 1          carnarvon -24.8667  113.6333     70.27        71          11
# 2             mirnyy  62.5353  113.9611     27.46        93         100
# 3            extrema -22.8547  -46.3183     65.43        92         100
# 4  port-aux-francais -49.3500   70.2167     39.85        60          77
#
#    Windspeed Country        Date
# 0       6.91      US  1683407187
# 1      10.63      AU  1683407281
# 2      16.20      RU  1683407282
# 3       2.35      BR  1683407282
# 4      29.57      TF  1683407282

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   kodiak  57.7900 -152.4072     42.31        81         100
# 1                carnarvon -24.8667  113.6333     70.27        71          11
# 2                   mirnyy  62.5353  113.9611     27.46        93         100
# 3                  extrema -22.8547  -46.3183     65.43        92         100
# 4        port-aux-francais -49.3500   70.2167     39.85        60          77
#
#          Windspeed Country        Date
# City_ID
# 0             6.91      US  1683407187
# 1            10.63      AU  1683407281
# 2            16.20      RU  1683407282
# 3             2.35      BR  1683407282
# 4            29.57      TF  1683407282

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
latitude = city_data_df["Lat"]
maiximum_temp = city_data_df["Max Temp"]
humid = city_data_df["Humidity"]
clouds = city_data_df["Cloudiness"]
winds = city_data_df["Windspeed"]

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(latitude, maiximum_temp, color= "pink", edgecolors= "red" )

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(latitude, humid, color="teal", edgecolors= 'black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidty(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(latitude, clouds, color = "green", edgecolors= "blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(latitude, winds, color = "magenta", edgecolors="purple")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speeds(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg_plot(x_values, y_values, title, txt_position):

    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))

    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,txt_position)
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         kodiak  57.7900 -152.4072     42.31        81         100
# 2         mirnyy  62.5353  113.9611     27.46        93         100
# 7        college  64.8569 -147.8028     51.75        41          75
# 11       talnakh  69.4865   88.3972     -1.97        98          74
# 12          bafq  31.6128   55.4107     73.63        13           0
#
#          Windspeed Country        Date
# City_ID
# 0             6.91      US  1683407187
# 2            16.20      RU  1683407282
# 7            11.50      US  1683407283
# 11            1.72      RU  1683407284
# 12            3.09      IR  1683407284

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                carnarvon -24.8667  113.6333     70.27        71          11
# 3                  extrema -22.8547  -46.3183     65.43        92         100
# 4        port-aux-francais -49.3500   70.2167     39.85        60          77
# 5                adamstown -25.0660 -130.1015     72.28        78         100
# 6                   callao -12.0667  -77.1500     75.49        69           0
#
#          Windspeed Country        Date
# City_ID
# 1            10.63      AU  1683407281
# 3             2.35      BR  1683407282
# 4            29.57      TF  1683407282
# 5             8.68      PN  1683407116
# 6            13.80      PE  1683407282

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Max Temp"]

lin_reg_plot(x_axis,y_axis, title= "Max Temperature", txt_position=(10, 20))
# Out:
# The r-squared is: -0.8454574683555872

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Max Temp"]

lin_reg_plot(x_axis, y_axis, title = "Max Temperature", txt_position= (-50, 80))
# Out:
# The r-squared is: 0.7938436756229506

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# The r-value of Latitude vs Temperature for the Northern Hemisphere is -0.8454. Which means that the r-value suggests theres is a strong negative coorealtion between the Latitude and the Temperature for the North Hemisphere.
#
# The r-value of Latitude vs Temperature for the Southern Hemisphere is 0.7938 . Which means that the r-value suggests theres is a positive coorealtion between the Latitude and the Temperature for the Southern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Humidity"]

lin_reg_plot(x_axis, y_axis, title="Humidity", txt_position=(55,10))
# Out:
# The r-squared is: 0.14284754978532707

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df ["Humidity"]

lin_reg_plot(x_axis, y_axis, title="Humidity", txt_position= (-15, 40))
# Out:
# The r-squared is: 0.11310196102672256

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# The r-value of Latitude vs Humidity for the Northern Hemisphere is 0.1428. Which means that the r-value suggests theres is a weak positive coorealtion between the Latitude and the Humidity for the North Hemisphere.
#
# The r-value of Latitude vs Humidity for the Southern Hemisphere is 0.1131. Which means that the r-value suggests theres is a weak positive coorealtion between the Latitude and the Humidity for the Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Cloudiness"]

lin_reg_plot(x_axis, y_axis, title="Cloudiness", txt_position=(55,15))
# Out:
# The r-squared is: 0.05671204965188177

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Cloudiness"]

lin_reg_plot(x_axis, y_axis, title="Cloudiness", txt_position=(-55,60))
# Out:
# The r-squared is: 0.009706636065359585

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# The r-value of Latitude vs Cloudiness for the Northern Hemisphere is 0.0567. Which means that the r-value suggests theres is a very weak positive coorealtion between the Latitude and the Cloudiness for the North Hemisphere.
#
# The r-value of Latitude vs Cloudiness for the Southern Hemisphere is 0.0097. Which means that the r-value suggests theres is a very weak positive coorealtion between the Latitude and the Cloudiness for the Southern Hemisphere

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Windspeed"]

lin_reg_plot(x_axis, y_axis, title="Windspeed", txt_position=(5, 25))
# Out:
# The r-squared is: -0.1372318613460248

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Windspeed"]

lin_reg_plot(x_axis, y_axis, title="Wind Speed", txt_position=(-40, 25))
# Out:
# The r-squared is: -0.25570280279117674

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# The r-value of Latitude vs Wind Speed for the Northern Hemisphere is -0.1372. Which means that the r-value suggests theres is a weak negative coorealtion between the Latitude and the Wind Speed for the North Hemisphere.
#
# The r-value of Latitude vs Wind Speed for the Southern Hemisphere is -0.2557. Which means that the r-value suggests theres is a weak negative coorealtion between the Latitude and the Wind Speed for the Southern Hemisphere.
